# %%
import uproot
import numpy as np
import pandas as pd
import awkward as ak
import matplotlib.pyplot as plt
import pickle
import os
from scipy.constants import c
import sys

sys.path.append("..")

DATA_DIR = "../mu3e_trigger_data"
ROOT_DATA_DIR = "../mu3e_root_data"
signal_data_file = f"{ROOT_DATA_DIR}/run_sig_simi-sort.root"
background_data_file = f"{ROOT_DATA_DIR}/run_bg_simi-sort.root"
e5_data_file = f"{ROOT_DATA_DIR}/run42_5e-sort.root"
familong_data_file = f"{ROOT_DATA_DIR}/run_familon_simi-sort.root"
signal_only_data_file = f"{ROOT_DATA_DIR}/run42_sig_only-sort.root"

HIT_COUNT_CUTOFF = 256
from src.data_preparation import convert_root_to_npy

# %%
convert_root_to_npy(
    file_path=signal_data_file,
out_dir=DATA_DIR,
    out_name="sig",
    padding_value=-999,
    hit_cutoff=HIT_COUNT_CUTOFF,
    add_layer_as_feature=True,
)
convert_root_to_npy(
    file_path=background_data_file,
    out_dir=DATA_DIR,
    out_name="bg",
    padding_value=-999,
    hit_cutoff=HIT_COUNT_CUTOFF,
    add_layer_as_feature=True,
)
convert_root_to_npy(
    file_path=e5_data_file,
    out_dir=DATA_DIR,
    out_name="5e",
    padding_value=-999,
    hit_cutoff=HIT_COUNT_CUTOFF,
    add_layer_as_feature=True,
)
convert_root_to_npy(
    file_path=familong_data_file,
    out_dir=DATA_DIR,
    out_name="familon",
    padding_value=-999,
    hit_cutoff=HIT_COUNT_CUTOFF,
    add_layer_as_feature=True,
)
convert_root_to_npy(
    file_path=signal_only_data_file,
    out_dir=DATA_DIR,
    out_name="sig_only",
    padding_value=-999,
    hit_cutoff=HIT_COUNT_CUTOFF,
    add_layer_as_feature=True,
)
# Out:
# Saved pixel spacetime to ../mu3e_trigger_data/sig_with_layer_pixel_spacetime.npy with shape (177028, 256, 5)
# Saved MPPC spacetime to ../mu3e_trigger_data/sig_with_layer_mppc_spacetime.npy with shape (177028, 256, 5)
# Saved pixel track labels to ../mu3e_trigger_data/sig_with_layer_pixel_track_labels.npy with shape (177028, 256, 6)
# Saved MPPC track labels to ../mu3e_trigger_data/sig_with_layer_mppc_track_labels.npy with shape (177028, 256, 6)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       1 convert_root_to_npy(
#       2     file_path=signal_data_file,
#       3 out_dir=DATA_DIR,
#    (...)
#       7     add_layer_as_feature=True,
#       8 )
# ----> 9 convert_root_to_npy(
#      10     file_path=background_data_file,
#      11     out_dir=DATA_DIR,
#      12     out_name="bg",
#      13     padding_value=-999,
#      14     hit_cutoff=HIT_COUNT_CUTOFF,
#      15     add_layer_as_feature=True,
#      16 )
#      17 convert_root_to_npy(
#      18     file_path=e5_data_file,
#      19     out_dir=DATA_DIR,
#    (...)
#      23     add_layer_as_feature=True,
#      24 )
#      25 convert_root_to_npy(
#      26     file_path=familong_data_file,
#      27     out_dir=DATA_DIR,
#    (...)
#      31     add_layer_as_feature=True,
#      32 )
#
# File ~/mu3e_trigger/notebooks_feature_plotting/../src/data_preparation/root_to_numpy.py:469, in convert_root_to_npy(file_path, out_dir, out_name, padding_value, hit_cutoff, add_layer_as_feature)
#     467 mppc_positions = file["alignment/mppcs"].arrays(library="pd")
#     468 fibre_positions = file["alignment/fibres"].arrays(library="pd")
# --> 469 event_data = file["mu3e"].arrays(library="pd")
#     470 if sensor_positions.empty or mppc_positions.empty or fibre_positions.empty:
#     471     raise ValueError("Sensor, MPPC, or fibre positions are empty.")
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:889, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     886                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     888 interp_options = {"ak_add_doc": ak_add_doc}
# --> 889 _ranges_or_baskets_to_arrays(
#     890     self,
#     891     ranges_or_baskets,
#     892     branchid_interpretation,
#     893     entry_start,
#     894     entry_stop,
#     895     decompression_executor,
#     896     interpretation_executor,
#     897     library,
#     898     arrays,
#     899     False,
#     900     interp_options,
#     901 )
#     903 # no longer needed; save memory
#     904 del ranges_or_baskets
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3195, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3193 if isinstance(obj, uproot.source.chunk.Chunk):
#    3194     args = range_args[(obj.start, obj.stop)]
# -> 3195     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3197 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
#    3198     interpretation_executor.submit(basket_to_array, obj)
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3112, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3110 try:
#    3111     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3112     basket = uproot.models.TBasket.Model_TBasket.read(
#    3113         chunk,
#    3114         cursor,
#    3115         {"basket_num": basket_num},
#    3116         hasbranches._file,
#    3117         hasbranches._file,
#    3118         branch,
#    3119     )
#    3120     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3121     if update_ranges_or_baskets:
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/model.py:854, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     852     forth_obj.add_node(forth_stash)
#     853     forth_obj.push_active_node(forth_stash)
# --> 854 self.read_members(chunk, cursor, context, file)
#     855 if forth_obj is not None:
#     856     forth_obj.pop_active_node()
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/models/TBasket.py:290, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     288 if compressed_bytes != uncompressed_bytes:
#     289     self._block_compression_info = []
# --> 290     uncompressed = uproot.compression.decompress(
#     291         chunk,
#     292         cursor,
#     293         {},
#     294         compressed_bytes,
#     295         uncompressed_bytes,
#     296         self._block_compression_info,
#     297     )
#     298     self._block_compression_info = tuple(self._block_compression_info)
#     299     self._raw_data = uncompressed.get(
#     300         0,
#     301         uncompressed_bytes,
#     302         uproot.source.cursor.Cursor(0),
#     303         context,
#     304     )
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/compression.py:463, in decompress(chunk, cursor, context, compressed_bytes, uncompressed_bytes, block_info)
#     458         if block_info is not None:
#     459             block_info.append(
#     460                 (decompressor.name, block_compressed_bytes, block_uncompressed_bytes)
#     461             )
# --> 463         uncompressed_bytestring = decompressor.decompress(
#     464             data, block_uncompressed_bytes
#     465         )
#     467         if len(uncompressed_bytestring) != block_uncompressed_bytes:
#     468             raise ValueError(
#     469                 f"""after successfully decompressing {num_blocks} blocks, a block of """
#     470                 f"""compressed size {block_compressed_bytes} decompressed to {len(uncompressed_bytestring)} bytes, but the """
#     471                 f"""block header expects {block_uncompressed_bytes} bytes.
#     472 in file {chunk.source.file_path}"""
#     473             )
#
# File ~/mu3e_trigger/venv/lib/python3.10/site-packages/uproot/compression.py:100, in _DecompressZLIB.decompress(self, data, uncompressed_bytes)
#      97 if self.library == "zlib":
#      98     import zlib
# --> 100     return zlib.decompress(data, bufsize=uncompressed_bytes)
#     102 elif self.library == "isal":
#     103     isal_zlib = uproot.extras.isal().isal_zlib
#
# KeyboardInterrupt:
